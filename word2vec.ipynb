# %% [markdown]
# # Creating a Vector representation of Words
# Following tensorflow's tutorial: https://www.tensorflow.org/tutorials/word2vec
# ##### This notebook guides throught the steps of creating a vectorbase of common words to use in natural language processing.

# %% [markdown]
# Required packages:

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
import matplotlib.pyplot as plt
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %% [markdown]
# Downloading word data to train on. Text from Wikipedia articles:

# %%
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Parse data into a list of strings:

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Number of words: ', len(vocabulary))
# Out:
# Number of words:  17005207

# %%
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5236, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=16, num_skips=2, skip_window=1)
for i in range(16):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5236 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of
# 2 of -> 195 term
# 2 of -> 3134 abuse
# 3134 abuse -> 46 first
# 3134 abuse -> 2 of
# 46 first -> 3134 abuse
# 46 first -> 59 used
# 59 used -> 46 first
# 59 used -> 156 against

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
num_steps = 200001
embeddings_list = []
with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0
    if step % 10000 == 0:
        final_embeddings = normalized_embeddings.eval()
        embeddings_list.append(final_embeddings.copy())

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 100000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
print(embeddings_list)
# Out:
# Initialized
# Average loss at step  0 :  299.36618042
# Nearest to that: overs, bhaktivedanta, mozart, columnist, cpm, incessant, carcinoma, condon,
# Nearest to as: clapping, falsified, mci, kajang, lizzie, issuing, marmite, vectorborne,
# Nearest to four: specialising, robberies, exoskeleton, fouls, izmir, steered, recommendations, operators,
# Nearest to be: rak, snake, equiv, profession, eclipses, couple, octavius, anchored,
# Nearest to their: weaned, consulship, conservancy, wharf, solidarity, countered, laden, lithuania,
# Nearest to by: stealthy, photo, supposition, whim, hector, furtherance, molarity, unfold,
# Nearest to zero: hover, reactionary, galatia, moria, incentives, dunstan, writer, atheism,
# Nearest to used: rancher, roamed, friz, disfigured, fang, lublin, doug, faltered,
# Nearest to to: journey, despatch, uganda, irc, griffey, unites, kidnapped, expending,
# Nearest to b: denies, longman, charcoal, consenting, tricky, francesco, tuareg, lms,
# Nearest to war: topologies, microvision, elitism, pali, hepworth, theogony, thicknesses, arminians,
# Nearest to united: caricature, msf, appalachians, koi, reefs, hog, cyclops, sir,
# Nearest to they: kee, menial, sobriquet, ethiopian, bijapur, disability, forehead, recreating,
# Nearest to d: aikido, lunda, dihedral, anand, composed, harappan, fellow, close,
# Nearest to up: columbia, tissues, telekom, gramophone, dhaka, conditioner, dunfermline, draws,
# Nearest to and: wrap, chant, bypass, bounding, consort, suffrage, cordless, dia,
# Average loss at step  2000 :  113.574332662
# Average loss at step  4000 :  52.6377516522
# Average loss at step  6000 :  33.1477802142
# Average loss at step  8000 :  23.6774123869
# Average loss at step  10000 :  17.920624131
# Average loss at step  12000 :  14.074130089
# Average loss at step  14000 :  11.7964008234
# Average loss at step  16000 :  9.83252730775
# Average loss at step  18000 :  8.56525923812
# Average loss at step  20000 :  7.99974609327
# Average loss at step  22000 :  7.01408611393
# Average loss at step  24000 :  6.8307247932
# Average loss at step  26000 :  6.71632872701
# Average loss at step  28000 :  6.34076986837
# Average loss at step  30000 :  5.9589675914
# Average loss at step  32000 :  5.93102668476
# Average loss at step  34000 :  5.71697699976
# Average loss at step  36000 :  5.79267893159
# Average loss at step  38000 :  5.56809803903
# Average loss at step  40000 :  5.27158944255
# Average loss at step  42000 :  5.35429999733
# Average loss at step  44000 :  5.24577769995
# Average loss at step  46000 :  5.22128532851
# Average loss at step  48000 :  5.22995487726
# Average loss at step  50000 :  5.01113065183
# Average loss at step  52000 :  5.03446193624
# Average loss at step  54000 :  5.19383985889
# Average loss at step  56000 :  5.04470792866
# Average loss at step  58000 :  5.0792965318
# Average loss at step  60000 :  4.95002293289
# Average loss at step  62000 :  4.99599242353
# Average loss at step  64000 :  4.83292348391
# Average loss at step  66000 :  4.61211495018
# Average loss at step  68000 :  4.95962734962
# Average loss at step  70000 :  4.90417311239
# Average loss at step  72000 :  4.73967816782
# Average loss at step  74000 :  4.79101570773
# Average loss at step  76000 :  4.7291368345
# Average loss at step  78000 :  4.80198916826
# Average loss at step  80000 :  4.81568095714
# Average loss at step  82000 :  4.76580597794
# Average loss at step  84000 :  4.74393704391
# Average loss at step  86000 :  4.77923996031
# Average loss at step  88000 :  4.728880283
# Average loss at step  90000 :  4.75982560349
# Average loss at step  92000 :  4.65186636031
# Average loss at step  94000 :  4.72706534147
# Average loss at step  96000 :  4.69584371984
# Average loss at step  98000 :  4.58296173513
# Average loss at step  100000 :  4.71400657725
# Nearest to that: which, this, but, however, microcebus, agouti, michelob, what,
# Nearest to as: kapoor, albury, ursus, agouti, when, microcebus, iit, raleigh,
# Nearest to four: five, three, six, seven, eight, two, zero, nine,
# Nearest to be: been, have, were, are, is, by, was, being,
# Nearest to their: its, his, her, the, some, our, peacocks, herbivore,
# Nearest to by: agouti, timecode, was, be, through, been, as, dasyprocta,
# Nearest to zero: five, eight, seven, four, nine, six, microcebus, three,
# Nearest to used: known, referred, aargau, circ, ursus, microcebus, symbolizes, recurrence,
# Nearest to to: ursus, would, upanija, agouti, can, will, coke, nine,
# Nearest to b: d, velocity, keto, UNK, ursus, six, microcebus, nn,
# Nearest to war: clauses, elitism, theogony, upanija, foreigners, parliaments, threads, pali,
# Nearest to united: caricature, lysine, reefs, trivially, kumar, gum, pelagius, sir,
# Nearest to they: we, he, there, you, it, who, not, she,
# Nearest to d: b, aikido, and, thaler, UNK, six, microcebus, seven,
# Nearest to up: them, him, down, blore, akita, tissues, chains, adelaide,
# Nearest to and: or, but, including, abet, ursus, circ, pulau, agouti,
# Average loss at step  102000 :  4.59728905356
# Average loss at step  104000 :  4.64890727448
# Average loss at step  106000 :  4.61944220781
# Average loss at step  108000 :  4.63046198452
# Average loss at step  110000 :  4.59919736314
# Average loss at step  112000 :  4.64361431706
# Average loss at step  114000 :  4.55039406419
# Average loss at step  116000 :  4.41875926507
# Average loss at step  118000 :  4.56151840794
# Average loss at step  120000 :  4.52262433863
# Average loss at step  122000 :  4.56738110352
# Average loss at step  124000 :  4.54701786959
# Average loss at step  126000 :  4.5505636636
# Average loss at step  128000 :  4.54589637017
# Average loss at step  130000 :  4.4561130417
# Average loss at step  132000 :  4.42337631345
# Average loss at step  134000 :  4.49693430495
# Average loss at step  136000 :  4.45456061888
# Average loss at step  138000 :  4.47032821369
# Average loss at step  140000 :  4.50842246902
# Average loss at step  142000 :  4.44709920359
# Average loss at step  144000 :  4.49371423233
# Average loss at step  146000 :  4.48536526346
# Average loss at step  148000 :  4.47922781742
# Average loss at step  150000 :  4.44924146676
# Average loss at step  152000 :  4.36973348171
# Average loss at step  154000 :  4.47351017541
# Average loss at step  156000 :  4.52340671229
# Average loss at step  158000 :  4.51348886752
# Average loss at step  160000 :  4.49946212435
# Average loss at step  162000 :  4.50348109889
# Average loss at step  164000 :  4.44791449916
# Average loss at step  166000 :  4.36170332146
# Average loss at step  168000 :  4.43644059956
# Average loss at step  170000 :  4.46630819774
# Average loss at step  172000 :  4.46822746581
# Average loss at step  174000 :  4.4233847369
# Average loss at step  176000 :  4.48427731001
# Average loss at step  178000 :  4.43591528821
# Average loss at step  180000 :  4.45729661739
# Average loss at step  182000 :  4.43461115515
# Average loss at step  184000 :  4.45272372055
# Average loss at step  186000 :  4.30063984859
# Average loss at step  188000 :  4.4375376842
# Average loss at step  190000 :  4.46671114516
# Average loss at step  192000 :  4.42353012431
# Average loss at step  194000 :  4.41834463835
# Average loss at step  196000 :  4.39548863244
# Average loss at step  198000 :  4.38603887653
# Average loss at step  200000 :  4.1233529042
# Nearest to that: which, however, what, but, bhaktivedanta, microcebus, michelob, agouti,
# Nearest to as: landesverband, albury, kapoor, when, agouti, michelob, ursus, iit,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to be: been, become, have, refer, were, being, are, cays,
# Nearest to their: its, his, her, our, the, your, my, some,
# Nearest to by: agouti, five, landesverband, af, dasyprocta, seven, was, napoleonic,
# Nearest to zero: five, six, seven, nine, four, eight, circ, three,
# Nearest to used: known, referred, called, considered, seen, available, spoken, landesverband,
# Nearest to to: would, ursus, upanija, landesverband, will, agouti, coke, might,
# Nearest to b: d, and, ebne, scottish, velocity, keto, nn, joy,
# Nearest to war: clauses, upanija, parliaments, midlands, wil, theogony, marko, administratively,
# Nearest to united: lysine, caricature, pelagius, taunus, supreme, trivially, landesverband, vertebra,
# Nearest to they: we, there, he, you, it, she, who, these,
# Nearest to d: b, and, thaler, yunnan, aikido, willi, scottish, nn,
# Nearest to up: them, down, him, off, out, back, akita, chains,
# Nearest to and: or, but, including, landesverband, hyi, abet, ursus, otimes,
# [array([[ 0.07283766, -0.09132069,  0.06381866, ..., -0.05117354,
#          0.15144542, -0.00708133],
#        [ 0.01216134,  0.1477263 ,  0.0762747 , ...,  0.02296177,
#          0.1553899 ,  0.07480996],
#        [ 0.0531549 ,  0.10484958, -0.04844893, ..., -0.07845252,
#          0.04469816,  0.15376371],
#        ...,
#        [ 0.08543441,  0.09034997,  0.09304305, ...,  0.0651181 ,
#          0.10955551,  0.01625821],
#        [ 0.13900904,  0.07124348, -0.06180375, ..., -0.03797951,
#         -0.06689373,  0.0794948 ],
#        [ 0.07534479, -0.01054577,  0.12675552, ..., -0.08277412,
#         -0.07031223,  0.04208723]], dtype=float32), array([[ 0.02786128,  0.03650358,  0.08644689, ..., -0.10415387,
#          0.13628051,  0.04934308],
#        [-0.07553662,  0.06446907,  0.01315514, ..., -0.04868122,
#          0.15564023,  0.00225434],
#        [ 0.10513072,  0.11517163,  0.03554638, ..., -0.1052421 ,
#          0.04650372,  0.15857899],
#        ...,
#        [ 0.08543441,  0.09034997,  0.09304305, ...,  0.0651181 ,
#          0.10955551,  0.01625821],
#        [ 0.13900904,  0.07124348, -0.06180375, ..., -0.03797951,
#         -0.06689373,  0.0794948 ],
#        [ 0.07534479, -0.01054577,  0.12675552, ..., -0.08277412,
#         -0.07031223,  0.04208723]], dtype=float32), array([[ 0.04863711,  0.03385707,  0.04379772, ..., -0.05901666,
#          0.11786367,  0.01281144],
#        [-0.03113006,  0.12386211, -0.00348773, ..., -0.0510047 ,
#          0.21163115, -0.00479968],
#        [ 0.11852824,  0.16422477, -0.02160631, ..., -0.10057642,
#          0.0501227 ,  0.14598902],
#        ...,
#        [ 0.08543441,  0.09034997,  0.09304305, ...,  0.0651181 ,
#          0.10955551,  0.01625821],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07534479, -0.01054577,  0.12675552, ..., -0.08277412,
#         -0.07031223,  0.04208723]], dtype=float32), array([[ 0.06367558,  0.04583599,  0.01357968, ..., -0.09245347,
#          0.1148645 ,  0.01349553],
#        [-0.06875279,  0.08826121, -0.01765538, ..., -0.01040048,
#          0.15935525,  0.00543475],
#        [ 0.12059038,  0.14902505, -0.0166972 , ..., -0.03480677,
#          0.04567835,  0.18931128],
#        ...,
#        [ 0.08543441,  0.09034997,  0.09304305, ...,  0.0651181 ,
#          0.10955551,  0.01625821],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07534479, -0.01054577,  0.12675552, ..., -0.08277412,
#         -0.07031223,  0.04208723]], dtype=float32), array([[ 0.09200691,  0.04813858,  0.02374807, ..., -0.07950651,
#          0.09582368, -0.00587076],
#        [-0.05872716,  0.1093109 , -0.02631182, ..., -0.03178342,
#          0.16294564, -0.01480894],
#        [ 0.11359335,  0.15725785, -0.02886558, ..., -0.07127967,
#          0.00448537,  0.15480617],
#        ...,
#        [ 0.08543441,  0.09034997,  0.09304305, ...,  0.0651181 ,
#          0.10955551,  0.01625821],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07534479, -0.01054577,  0.12675552, ..., -0.08277412,
#         -0.07031223,  0.04208723]], dtype=float32), array([[  5.78779168e-02,   1.38627449e-02,   3.58540863e-02, ...,
#          -8.33315849e-02,   1.05153210e-01,   1.30364224e-02],
#        [ -4.21431400e-02,   4.51528430e-02,   1.02356913e-04, ...,
#          -3.85854766e-02,   1.55631512e-01,   3.51452976e-02],
#        [  1.38606608e-01,   1.51958421e-01,  -1.04062296e-02, ...,
#          -8.69774148e-02,  -9.37149581e-03,   1.78210244e-01],
#        ...,
#        [  8.90761912e-02,   1.22049600e-01,   9.68546644e-02, ...,
#           5.13737462e-02,   1.50548354e-01,   5.51098622e-02],
#        [  1.43666491e-01,   9.30694938e-02,  -5.35222627e-02, ...,
#          -4.36961427e-02,  -4.07370739e-02,   1.01116657e-01],
#        [  7.53447935e-02,  -1.05457744e-02,   1.26755521e-01, ...,
#          -8.27741176e-02,  -7.03122318e-02,   4.20872271e-02]], dtype=float32), array([[ 0.07590062,  0.04140662,  0.05630285, ..., -0.05399536,
#          0.0339123 ,  0.03096208],
#        [-0.08819114,  0.17828758, -0.02778889, ...,  0.01152817,
#          0.17325498, -0.00732464],
#        [ 0.12963493,  0.17209226, -0.02463903, ..., -0.05482613,
#          0.03714784,  0.1530517 ],
#        ...,
#        [ 0.08907619,  0.1220496 ,  0.09685466, ...,  0.05137375,
#          0.15054835,  0.05510986],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07534479, -0.01054577,  0.12675552, ..., -0.08277412,
#         -0.07031223,  0.04208723]], dtype=float32), array([[ 0.06730222,  0.03182724,  0.0504155 , ..., -0.07694031,
#          0.04752093,  0.03905514],
#        [-0.00306355,  0.14158244, -0.02556954, ..., -0.01476972,
#          0.16288543,  0.06996123],
#        [ 0.11148128,  0.15293449, -0.02114154, ..., -0.08174416,
#          0.05814634,  0.16475073],
#        ...,
#        [ 0.08907619,  0.1220496 ,  0.09685466, ...,  0.05137375,
#          0.15054835,  0.05510986],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07838355,  0.00990208,  0.12969266, ..., -0.08297631,
#         -0.04292699,  0.06190391]], dtype=float32), array([[ 0.06208548,  0.07316636,  0.03068836, ..., -0.05404384,
#          0.09975766, -0.0348476 ],
#        [-0.07036021,  0.11088371,  0.01462312, ...,  0.00394336,
#          0.13232788,  0.0118666 ],
#        [ 0.10476489,  0.1655817 , -0.00225967, ..., -0.06259306,
#          0.03146954,  0.16030638],
#        ...,
#        [ 0.08907619,  0.1220496 ,  0.09685466, ...,  0.05137375,
#          0.15054835,  0.05510986],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07838355,  0.00990208,  0.12969266, ..., -0.08297631,
#         -0.04292699,  0.06190391]], dtype=float32), array([[ 0.09877061,  0.09805868,  0.04790022, ..., -0.07032908,
#          0.07940797,  0.04918583],
#        [-0.04039041,  0.1266173 , -0.01888717, ..., -0.01083665,
#          0.1773265 ,  0.01410776],
#        [ 0.13274334,  0.13344982, -0.04602292, ..., -0.06151353,
#         -0.00185513,  0.16452089],
#        ...,
#        [ 0.08907619,  0.1220496 ,  0.09685466, ...,  0.05137375,
#          0.15054835,  0.05510986],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07802147,  0.01671025,  0.12979069, ..., -0.08425938,
#         -0.03255775,  0.06803661]], dtype=float32), array([[ 0.05479362,  0.09150894,  0.00258567, ..., -0.05949264,
#          0.05250103,  0.03198275],
#        [-0.02034027,  0.10014352, -0.01742704, ..., -0.00859694,
#          0.17482194,  0.0172304 ],
#        [ 0.16160905,  0.14305444, -0.00830672, ..., -0.06194264,
#          0.03230952,  0.13610725],
#        ...,
#        [ 0.08907619,  0.1220496 ,  0.09685466, ...,  0.05137375,
#          0.15054835,  0.05510986],
#        [ 0.14366649,  0.09306949, -0.05352226, ..., -0.04369614,
#         -0.04073707,  0.10111666],
#        [ 0.07802147,  0.01671025,  0.12979069, ..., -0.08425938,
#         -0.03255775,  0.06803661]], dtype=float32), array([[ 0.05913454,  0.06146162,  0.05598595, ..., -0.0598409 ,
#          0.08905787,  0.02556864],
#        [-0.04064823,  0.12543146, -0.00382096, ..., -0.01541064,
#          0.18807866, -0.03277607],
#        [ 0.12683411,  0.16507977, -0.0274037 , ..., -0.06768621,
#          0.02053054,  0.15977266],
#        ...,
#        [ 0.08907619,  0.1220496 ,  0.09685466, ...,  0.05137375,
#          0.15054835,  0.05510986],
#        [ 0.14204103,  0.1126446 , -0.04369551, ..., -0.0487505 ,
#         -0.00758875,  0.1202745 ],
#        [ 0.0780336 ,  0.01839768,  0.12971839, ..., -0.08441976,
#         -0.03005377,  0.06954334]], dtype=float32), array([[ 0.12459946,  0.07645203,  0.0701574 , ..., -0.0336574 ,
#          0.07738756,  0.04432371],
#        [-0.05247341,  0.12341302,  0.02241828, ..., -0.01717496,
#          0.16785353,  0.02330368],
#        [ 0.12155814,  0.14657271, -0.01325725, ..., -0.04896542,
#          0.02849693,  0.1381963 ],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.14105628,  0.11379998, -0.04274968, ..., -0.04886601,
#         -0.00501758,  0.12202077],
#        [ 0.0780336 ,  0.01839768,  0.12971839, ..., -0.08441976,
#         -0.03005377,  0.06954334]], dtype=float32), array([[ 0.07087651,  0.07407481, -0.01273397, ..., -0.06781884,
#          0.03672503,  0.02948303],
#        [-0.03060678,  0.12063309, -0.02159414, ...,  0.02323885,
#          0.18267916,  0.0515279 ],
#        [ 0.15388833,  0.16126986, -0.03178894, ..., -0.01971085,
#          0.04574675,  0.14794189],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.14080964,  0.11497439, -0.04191259, ..., -0.04932685,
#         -0.0018743 ,  0.12326758],
#        [ 0.0780336 ,  0.01839768,  0.12971839, ..., -0.08441976,
#         -0.03005377,  0.06954334]], dtype=float32), array([[ 0.04674698,  0.13104554,  0.02213262, ..., -0.04775324,
#          0.07598491,  0.0443636 ],
#        [-0.03271138,  0.126653  , -0.04658891, ..., -0.0324768 ,
#          0.20877501,  0.03705128],
#        [ 0.12743844,  0.14446238, -0.03463136, ..., -0.050815  ,
#          0.04729532,  0.17518511],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.14080964,  0.11497439, -0.04191259, ..., -0.04932685,
#         -0.0018743 ,  0.12326758],
#        [ 0.0780336 ,  0.01839768,  0.12971839, ..., -0.08441976,
#         -0.03005377,  0.06954334]], dtype=float32), array([[ 0.06309731,  0.11022498,  0.01198188, ..., -0.00433662,
#          0.04173819,  0.04869974],
#        [-0.05492818,  0.10832912,  0.0152505 , ..., -0.00697183,
#          0.1751959 , -0.02856944],
#        [ 0.14431354,  0.15202151, -0.00128457, ..., -0.05031599,
#          0.03495906,  0.12948693],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.14018476,  0.11537775, -0.04172132, ..., -0.04940366,
#         -0.00097757,  0.12383176],
#        [ 0.0780336 ,  0.01839768,  0.12971839, ..., -0.08441976,
#         -0.03005377,  0.06954334]], dtype=float32), array([[ 0.08326352,  0.1215025 ,  0.00826408, ..., -0.06501983,
#          0.07061834,  0.01878691],
#        [-0.05485202,  0.15405037, -0.07178404, ..., -0.00416841,
#          0.19837807, -0.00690037],
#        [ 0.13478057,  0.16993544, -0.02867473, ..., -0.04256407,
#          0.02058008,  0.13720328],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.13986856,  0.11559691, -0.04147267, ..., -0.04954842,
#         -0.00071844,  0.12377442],
#        [ 0.07932146,  0.02420262,  0.12922463, ..., -0.0848435 ,
#         -0.0226578 ,  0.07436503]], dtype=float32), array([[ 0.03048105,  0.10608919,  0.00781356, ..., -0.04310949,
#          0.06076504,  0.06249313],
#        [-0.06742889,  0.15951368, -0.05054771, ..., -0.06343871,
#          0.16965827, -0.0065741 ],
#        [ 0.14620876,  0.18727307, -0.03808704, ..., -0.05628078,
#         -0.01240238,  0.13385367],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.13986856,  0.11559691, -0.04147267, ..., -0.04954842,
#         -0.00071844,  0.12377442],
#        [ 0.07932146,  0.02420262,  0.12922463, ..., -0.0848435 ,
#         -0.0226578 ,  0.07436503]], dtype=float32), array([[ 0.08423075,  0.11481871,  0.01152752, ...,  0.00602695,
#          0.05100008,  0.03005055],
#        [-0.0402273 ,  0.15437934, -0.05622431, ...,  0.00098942,
#          0.16427119,  0.062461  ],
#        [ 0.17220639,  0.15548085, -0.00621032, ..., -0.05041856,
#          0.02064572,  0.13824274],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.13943663,  0.11614145, -0.04102118, ..., -0.04943348,
#          0.00083731,  0.12420526],
#        [ 0.07932146,  0.02420262,  0.12922463, ..., -0.0848435 ,
#         -0.0226578 ,  0.07436503]], dtype=float32), array([[ 0.0563365 ,  0.07697163,  0.02194791, ..., -0.03320857,
#          0.1100888 ,  0.06068926],
#        [-0.00377568,  0.0834684 , -0.0814829 , ..., -0.01462314,
#          0.17986958,  0.04790605],
#        [ 0.16066428,  0.16213076, -0.05319671, ..., -0.06666216,
#          0.03925299,  0.15713443],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.13926442,  0.11612335, -0.04103245, ..., -0.0493451 ,
#          0.00166029,  0.12431175],
#        [ 0.07932146,  0.02420262,  0.12922463, ..., -0.0848435 ,
#         -0.0226578 ,  0.07436503]], dtype=float32), array([[ 0.02189382,  0.09913668, -0.02635112, ..., -0.0086574 ,
#          0.01493038,  0.00854168],
#        [-0.04353452,  0.05987166,  0.00899058, ..., -0.04000878,
#          0.14390896, -0.01887183],
#        [ 0.15644497,  0.16269769,  0.02785836, ..., -0.08654906,
#         -0.05165763,  0.07759495],
#        ...,
#        [ 0.08895639,  0.12359296,  0.09735602, ...,  0.05055853,
#          0.15246645,  0.05749783],
#        [ 0.13926442,  0.11612335, -0.04103245, ..., -0.0493451 ,
#          0.00166029,  0.12431175],
#        [ 0.07932146,  0.02420262,  0.12922463, ..., -0.0848435 ,
#         -0.0226578 ,  0.07436503]], dtype=float32)]

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(15, 15))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.show()

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE

  finalembs = embeddings_list[-1]
  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(finalembs[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
